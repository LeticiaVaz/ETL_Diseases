# %%
import pandas as pd
from sqlalchemy import create_engine
import datetime
import numpy as np
from datetime import datetime as dt

# %% [markdown]
# ### Store CSV into DataFrame

# %%
ebola_csv = "Resources/ebola_data.csv"
ebola_df = pd.read_csv(ebola_csv)

# %%
covid_csv = "Resources/covid_data.csv"
covid_df = pd.read_csv(covid_csv)

# %%
sars_csv = "Resources/sars_data.csv"
sars_df = pd.read_csv(sars_csv)

# %%
swineflu_csv = "Resources/swineflu.csv"
swineflu_df = pd.read_csv(swineflu_csv,encoding="ISO-8859-1")

# %% [markdown]
# # EBOLA DATA

# %%
#### Create new data with select columns
new_ebola_df = ebola_df[['id','Country', 'Date','No. of confirmed cases','No. of confirmed deaths']].copy()
new_ebola_df.head()
# Out:
#    id       Country       Date  No. of confirmed cases  \
# 0   1        Guinea  8/29/2014                   482.0
# 1   2       Nigeria  8/29/2014                    15.0
# 2   3  Sierra Leone  8/29/2014                   935.0
# 3   4       Liberia  8/29/2014                   322.0
# 4   5  Sierra Leone   9/5/2014                  1146.0
#
#    No. of confirmed deaths
# 0                    287.0
# 1                      6.0
# 2                    380.0
# 3                    225.0
# 4                    443.0

# %%
### Clean DataFrame
ebola_virus=new_ebola_df.rename(columns={"Date": "date","No. of confirmed cases": "cases_confirmed", "No. of confirmed deaths": "deaths_confirmed","Country": "country"})

ebola_virus.style.format({
    'cases_confirmed': '{:,.0f}'.format,
    'deaths_confirmed': '{:,.0f}'.format,
})
ebola_virus.head()
# Out:
#    id       country       date  cases_confirmed  deaths_confirmed
# 0   1        Guinea  8/29/2014            482.0             287.0
# 1   2       Nigeria  8/29/2014             15.0               6.0
# 2   3  Sierra Leone  8/29/2014            935.0             380.0
# 3   4       Liberia  8/29/2014            322.0             225.0
# 4   5  Sierra Leone   9/5/2014           1146.0             443.0

# %% [markdown]
# # CORONA DATA

# %%
# Preview dataframe
covid_df.head()
# Out:
#    SNo ObservationDate Province/State  Country/Region      Last Update  \
# 0    1      01/22/2020          Anhui  Mainland China  1/22/2020 17:00
# 1    2      01/22/2020        Beijing  Mainland China  1/22/2020 17:00
# 2    3      01/22/2020      Chongqing  Mainland China  1/22/2020 17:00
# 3    4      01/22/2020         Fujian  Mainland China  1/22/2020 17:00
# 4    5      01/22/2020          Gansu  Mainland China  1/22/2020 17:00
#
#    Confirmed  Deaths  Recovered
# 0        1.0     0.0        0.0
# 1       14.0     0.0        0.0
# 2        6.0     0.0        0.0
# 3        1.0     0.0        0.0
# 4        0.0     0.0        0.0

# %%
# Define needed columns
col = ['SNo', 'Country/Region', 'ObservationDate', 'Deaths']

# Create copy of dataframe using columns above
new_covid_df = covid_df[col].copy()

# Normalize column names of dataframe and preview
new_covid_df = new_covid_df.rename(columns={'SNo':'id', 'Country/Region':'country', 'ObservationDate':'date', 'Deaths':'deaths'})
new_covid_df.head()
# Out:
#    id         country        date  deaths
# 0   1  Mainland China  01/22/2020     0.0
# 1   2  Mainland China  01/22/2020     0.0
# 2   3  Mainland China  01/22/2020     0.0
# 3   4  Mainland China  01/22/2020     0.0
# 4   5  Mainland China  01/22/2020     0.0

# %%
# Review stats of dataframe
new_covid_df.describe()
# Out:
#                 id       deaths
# count  3395.000000  3395.000000
# mean   1698.000000    17.756112
# std     980.196409   187.195366
# min       1.000000     0.000000
# 25%     849.500000     0.000000
# 50%    1698.000000     0.000000
# 75%    2546.500000     1.000000
# max    3395.000000  2871.000000

# %%
# Group by date and country
new_covid_df = new_covid_df.groupby(['date', 'country'])

# %%
# Sum deaths on group by object and preview
deaths = new_covid_df['deaths'].sum()
deaths.head()
# Out:
# date        country
# 01/22/2020  Hong Kong          0.0
#             Japan              0.0
#             Macau              0.0
#             Mainland China    17.0
#             South Korea        0.0
# Name: deaths, dtype: float64

# %%
# Transformed data ready to be loaded to db
new_covid_df.head()
# Out:
#         id         country        date  deaths
# 0        1  Mainland China  01/22/2020     0.0
# 1        2  Mainland China  01/22/2020     0.0
# 2        3  Mainland China  01/22/2020     0.0
# 3        4  Mainland China  01/22/2020     0.0
# 4        5  Mainland China  01/22/2020     0.0
# ...    ...             ...         ...     ...
# 3372  3373          Poland  03/04/2020     0.0
# 3373  3374    Saudi Arabia  03/04/2020     0.0
# 3374  3375       Sri Lanka  03/04/2020     0.0
# 3375  3376         Tunisia  03/04/2020     0.0
# 3390  3391         Ukraine  03/04/2020     0.0
#
# [1978 rows x 4 columns]

# %%
# Transformed data ready to be loaded to db
new_covid_df.head()
# Out:
#         id         country        date  deaths
# 0        1  Mainland China  01/22/2020     0.0
# 1        2  Mainland China  01/22/2020     0.0
# 2        3  Mainland China  01/22/2020     0.0
# 3        4  Mainland China  01/22/2020     0.0
# 4        5  Mainland China  01/22/2020     0.0
# ...    ...             ...         ...     ...
# 3372  3373          Poland  03/04/2020     0.0
# 3373  3374    Saudi Arabia  03/04/2020     0.0
# 3374  3375       Sri Lanka  03/04/2020     0.0
# 3375  3376         Tunisia  03/04/2020     0.0
# 3390  3391         Ukraine  03/04/2020     0.0
#
# [1978 rows x 4 columns]

# %% [markdown]
# # SARS DATA

# %%
#View dataset
sars_df.head()
# Out:
#          Date               Country  Cumulative number of case(s)  \
# 0  2003-03-17               Germany                             1
# 1  2003-03-17                Canada                             8
# 2  2003-03-17             Singapore                            20
# 3  2003-03-17  Hong Kong SAR, China                            95
# 4  2003-03-17           Switzerland                             2
#
#    Number of deaths  Number recovered
# 0                 0                 0
# 1                 2                 0
# 2                 0                 0
# 3                 1                 0
# 4                 0                 0

# %%
#Select columns for ETL transfer
new_sars_df = sars_df[['Country', 'Date', 'Cumulative number of case(s)', 'Number of deaths']].copy()
new_sars_df.head()
# Out:
#                 Country        Date  Cumulative number of case(s)  \
# 0               Germany  2003-03-17                             1
# 1                Canada  2003-03-17                             8
# 2             Singapore  2003-03-17                            20
# 3  Hong Kong SAR, China  2003-03-17                            95
# 4           Switzerland  2003-03-17                             2
#
#    Number of deaths
# 0                 0
# 1                 2
# 2                 0
# 3                 1
# 4                 0

# %%
#Change column names
sars_virus = new_sars_df.rename(columns={'Country':'country', 'Date':'date', 'Cumulative number of case(s)':'cases_confirmed', 'Number of deaths':'deaths_confirmed'})
sars_virus
# Out:
#                    country        date  cases_confirmed  deaths_confirmed
# 0                  Germany  2003-03-17                1                 0
# 1                   Canada  2003-03-17                8                 2
# 2                Singapore  2003-03-17               20                 0
# 3     Hong Kong SAR, China  2003-03-17               95                 1
# 4              Switzerland  2003-03-17                2                 0
# ...                    ...         ...              ...               ...
# 2533           Switzerland  2003-07-11                1                 0
# 2534              Thailand  2003-07-11                9                 2
# 2535        United Kingdom  2003-07-11                4                 0
# 2536         United States  2003-07-11               75                 0
# 2537              Viet Nam  2003-07-11               63                 5
#
# [2538 rows x 4 columns]

# %%
    #Review data
sars_virus.describe()
# Out:
#        cases_confirmed  deaths_confirmed
# count      2538.000000       2538.000000
# mean        219.211978         17.812845
# std         825.024564         61.425627
# min           0.000000          0.000000
# 25%           1.000000          0.000000
# 50%           3.000000          0.000000
# 75%          14.750000          2.000000
# max        5329.000000        348.000000

# %%
#View data for revelent information
#sars_deaths = sars_virus.groupby(['date', 'country'])

# %%
#group data to verify clean
total_deaths = sars_deaths['deaths_confirmed'].sum()
total_deaths
# Out:
# date        country
# 2003-03-17  Canada                   2
#             Germany                  0
#             Hong Kong SAR, China     1
#             Singapore                0
#             Switzerland              0
#                                     ..
# 2003-07-11  Taiwan, China           84
#             Thailand                 2
#             United Kingdom           0
#             United States            0
#             Viet Nam                 5
# Name: deaths_confirmed, Length: 2537, dtype: int64

# %%
#View clean data
total_deaths_df = pd.DataFrame(total_deaths)
total_deaths_df.head()
# Out:
#                                  deaths_confirmed
# date       country
# 2003-03-17 Canada                               2
#            Germany                              0
#            Hong Kong SAR, China                 1
#            Singapore                            0
#            Switzerland                          0

# %%
#FINAL DATA SET
sars_virus.head()
# Out:
#                 country        date  cases_confirmed  deaths_confirmed
# 0               Germany  2003-03-17                1                 0
# 1                Canada  2003-03-17                8                 2
# 2             Singapore  2003-03-17               20                 0
# 3  Hong Kong SAR, China  2003-03-17               95                 1
# 4           Switzerland  2003-03-17                2                 0

# %% [markdown]
# # SWINE FLU DATA

# %%
swineflu_df.describe()
# Out:
#                 id         Cases       Deaths
# count  1822.000000   1822.000000  1821.000000
# mean    911.500000    901.063666     4.315761
# std     526.110413   5264.291392    25.793340
# min       1.000000      1.000000     0.000000
# 25%     456.250000      3.000000     0.000000
# 50%     911.500000     13.500000     0.000000
# 75%    1366.750000     88.750000     0.000000
# max    1822.000000  94512.000000   429.000000

# %%
swineflu_df
# Out:
#         id                   Country  Cases  Deaths     Update Time
# 0        1                   Algeria      5     0.0   7/6/2009 9:00
# 1        2       Antigua and Barbuda      2     0.0   7/6/2009 9:00
# 2        3                 Argentina   2485    60.0   7/6/2009 9:00
# 3        4                 Australia   5298    10.0   7/6/2009 9:00
# 4        5                   Austria     19     0.0   7/6/2009 9:00
# ...    ...                       ...    ...     ...             ...
# 1817  1818                  Thailand      2     0.0  5/23/2009 8:00
# 1818  1819                    Turkey      2     0.0  5/23/2009 8:00
# 1819  1820            United Kingdom    117     0.0  5/23/2009 8:00
# 1820  1821  United States of America   6552     9.0  5/23/2009 8:00
# 1821  1822               Grand Total  12022    86.0  5/23/2009 8:00
#
# [1822 rows x 5 columns]

# %%
swineflu_df=swineflu_df.rename(columns={"Update Time": "date","Cases": "cases_confirmed", "Deaths": "deaths_confirmed","Country": "country"})

# %%
swineflu_df
# Out:
#         id                   country  cases_confirmed  deaths_confirmed  \
# 0        1                   Algeria                5               0.0
# 1        2       Antigua and Barbuda                2               0.0
# 2        3                 Argentina             2485              60.0
# 3        4                 Australia             5298              10.0
# 4        5                   Austria               19               0.0
# ...    ...                       ...              ...               ...
# 1817  1818                  Thailand                2               0.0
# 1818  1819                    Turkey                2               0.0
# 1819  1820            United Kingdom              117               0.0
# 1820  1821  United States of America             6552               9.0
# 1821  1822               Grand Total            12022              86.0
#
#                 date
# 0      7/6/2009 9:00
# 1      7/6/2009 9:00
# 2      7/6/2009 9:00
# 3      7/6/2009 9:00
# 4      7/6/2009 9:00
# ...              ...
# 1817  5/23/2009 8:00
# 1818  5/23/2009 8:00
# 1819  5/23/2009 8:00
# 1820  5/23/2009 8:00
# 1821  5/23/2009 8:00
#
# [1822 rows x 5 columns]

# %%
swineflu_df.dtypes
# Out:
# id                    int64
# country              object
# cases_confirmed       int64
# deaths_confirmed    float64
# date                 object
# dtype: object

# %%
print(swineflu_df['date'])
# Out:
# 0        7/6/2009 9:00
# 1        7/6/2009 9:00
# 2        7/6/2009 9:00
# 3        7/6/2009 9:00
# 4        7/6/2009 9:00
#              ...
# 1817    5/23/2009 8:00
# 1818    5/23/2009 8:00
# 1819    5/23/2009 8:00
# 1820    5/23/2009 8:00
# 1821    5/23/2009 8:00
# Name: date, Length: 1822, dtype: object

# %%
#swineflu_df['date'] = swineflu_df['date'].dt.normalize()
swineflu_df['date'] = pd.to_datetime(swineflu_df['date'], errors='coerce').dt.date

# %%
swineflu_df
# Out:
#         id                   country  cases_confirmed  deaths_confirmed  \
# 0        1                   Algeria                5               0.0
# 1        2       Antigua and Barbuda                2               0.0
# 2        3                 Argentina             2485              60.0
# 3        4                 Australia             5298              10.0
# 4        5                   Austria               19               0.0
# ...    ...                       ...              ...               ...
# 1817  1818                  Thailand                2               0.0
# 1818  1819                    Turkey                2               0.0
# 1819  1820            United Kingdom              117               0.0
# 1820  1821  United States of America             6552               9.0
# 1821  1822               Grand Total            12022              86.0
#
#             date
# 0     2009-07-06
# 1     2009-07-06
# 2     2009-07-06
# 3     2009-07-06
# 4     2009-07-06
# ...          ...
# 1817  2009-05-23
# 1818  2009-05-23
# 1819  2009-05-23
# 1820  2009-05-23
# 1821  2009-05-23
#
# [1822 rows x 5 columns]

# %%
swineflu_df.count()
# Out:
# id                  1822
# country             1822
# cases_confirmed     1822
# deaths_confirmed    1821
# date                1822
# dtype: int64

# %%
swineflu_virus = swineflu_df
swineflu_virus.head()
# Out:
#    id              country  cases_confirmed  deaths_confirmed        date
# 0   1              Algeria                5               0.0  2009-07-06
# 1   2  Antigua and Barbuda                2               0.0  2009-07-06
# 2   3            Argentina             2485              60.0  2009-07-06
# 3   4            Australia             5298              10.0  2009-07-06
# 4   5              Austria               19               0.0  2009-07-06

# %% [markdown]
# ### Connect to local database

# %%
rds_connection_string = "postgres:postgres@localhost:5432/virus_db"
engine = create_engine(f'postgresql://{rds_connection_string}')

# %% [markdown]
# ### Check for tables

# %%
engine.table_names()
# Out:
# ['ebola_virus', 'corona_virus', 'sars_virus', 'swineflu_virus']

# %% [markdown]
# ### Use pandas to load csv converted DataFrame into database

# %%
ebola_virus.to_sql(name='country', con=engine, if_exists='append', index=False)

# %%
sars_virus.to_sql(name='country', con=engine, if_exists='append', index=False)

# %%
swineflu_virus.to_sql(name='country', con=engine, if_exists='append', index=False)

# %%
corona_virus.to_sql(name='country', con=engine, if_exists='append', index=False)
# Out:
# ---------------------------------------------------------------------------
# UndefinedColumn                           Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1228                     self.dialect.do_executemany(
# -> 1229                         cursor, statement, parameters, context
#    1230                     )
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\dialects\postgresql\psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     853         if self.executemany_mode is EXECUTEMANY_DEFAULT:
# --> 854             cursor.executemany(statement, parameters)
#     855             return
#
# UndefinedColumn: column "deaths" of relation "country" does not exist
# LINE 1: INSERT INTO country (id, country, date, deaths) VALUES (1, '...
#                                                 ^
#
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# <ipython-input-83-177737ca8f33> in <module>
# ----> 1 corona_virus.to_sql(name='country', con=engine, if_exists='append', index=False)
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2710             chunksize=chunksize,
#    2711             dtype=dtype,
# -> 2712             method=method,
#    2713         )
#    2714
#
# ~\Anaconda3\lib\site-packages\pandas\io\sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#     516         chunksize=chunksize,
#     517         dtype=dtype,
# --> 518         method=method,
#     519     )
#     520
#
# ~\Anaconda3\lib\site-packages\pandas\io\sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1318         )
#    1319         table.create()
# -> 1320         table.insert(chunksize, method=method)
#    1321         if not name.isdigit() and not name.islower():
#    1322             # check for potentially case sensitivity issues (GH7815)
#
# ~\Anaconda3\lib\site-packages\pandas\io\sql.py in insert(self, chunksize, method)
#     754
#     755                 chunk_iter = zip(*[arr[start_i:end_i] for arr in data_list])
# --> 756                 exec_insert(conn, keys, chunk_iter)
#     757
#     758     def _query_iterator(
#
# ~\Anaconda3\lib\site-packages\pandas\io\sql.py in _execute_insert(self, conn, keys, data_iter)
#     668         """
#     669         data = [dict(zip(keys, row)) for row in data_iter]
# --> 670         conn.execute(self.table.insert(), data)
#     671
#     672     def _execute_insert_multi(self, conn, keys, data_iter):
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in execute(self, object_, *multiparams, **params)
#     986             raise exc.ObjectNotExecutableError(object_)
#     987         else:
# --> 988             return meth(self, multiparams, params)
#     989
#     990     def _execute_function(self, func, multiparams, params):
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\sql\elements.py in _execute_on_connection(self, connection, multiparams, params)
#     285     def _execute_on_connection(self, connection, multiparams, params):
#     286         if self.supports_execution:
# --> 287             return connection._execute_clauseelement(self, multiparams, params)
#     288         else:
#     289             raise exc.ObjectNotExecutableError(self)
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_clauseelement(self, elem, multiparams, params)
#    1105             distilled_params,
#    1106             compiled_sql,
# -> 1107             distilled_params,
#    1108         )
#    1109         if self._has_events or self.engine._has_events:
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1251         except BaseException as e:
#    1252             self._handle_dbapi_exception(
# -> 1253                 e, statement, parameters, cursor, context
#    1254             )
#    1255
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1471                 util.raise_from_cause(newraise, exc_info)
#    1472             elif should_wrap:
# -> 1473                 util.raise_from_cause(sqlalchemy_exception, exc_info)
#    1474             else:
#    1475                 util.reraise(*exc_info)
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_from_cause(exception, exc_info)
#     396     exc_type, exc_value, exc_tb = exc_info
#     397     cause = exc_value if exc_value is not exception else None
# --> 398     reraise(type(exception), exception, tb=exc_tb, cause=cause)
#     399
#     400
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\util\compat.py in reraise(tp, value, tb, cause)
#     150             value.__cause__ = cause
#     151         if value.__traceback__ is not tb:
# --> 152             raise value.with_traceback(tb)
#     153         raise value
#     154
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1227                 if not evt_handled:
#    1228                     self.dialect.do_executemany(
# -> 1229                         cursor, statement, parameters, context
#    1230                     )
#    1231             elif not parameters and context.no_parameters:
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\dialects\postgresql\psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     852     def do_executemany(self, cursor, statement, parameters, context=None):
#     853         if self.executemany_mode is EXECUTEMANY_DEFAULT:
# --> 854             cursor.executemany(statement, parameters)
#     855             return
#     856
#
# ProgrammingError: (psycopg2.errors.UndefinedColumn) column "deaths" of relation "country" does not exist
# LINE 1: INSERT INTO country (id, country, date, deaths) VALUES (1, '...
#                                                 ^
#
# [SQL: INSERT INTO country (id, country, date, deaths) VALUES (%(id)s, %(country)s, %(date)s, %(deaths)s)]
# [parameters: ({'id': 1, 'country': 'Mainland China', 'date': '01/22/2020', 'deaths': 0.0}, {'id': 2, 'country': 'Mainland China', 'date': '01/22/2020', 'deaths': 0.0}, {'id': 3, 'country': 'Mainland China', 'date': '01/22/2020', 'deaths': 0.0}, {'id': 4, 'country': 'Mainland China', 'date': '01/22/2020', 'deaths': 0.0}, {'id': 5, 'country': 'Mainland China', 'date': '01/22/2020', 'deaths': 0.0}, {'id': 6, 'country': 'Mainland China', 'date': '01/22/2020', 'deaths': 0.0}, {'id': 7, 'country': 'Mainland China', 'date': '01/22/2020', 'deaths': 0.0}, {'id': 8, 'country': 'Mainland China', 'date': '01/22/2020', 'deaths': 0.0}  ... displaying 10 of 3395 total bound parameter sets ...  {'id': 3394, 'country': 'US', 'date': '03/04/2020', 'deaths': 0.0}, {'id': 3395, 'country': 'US', 'date': '03/04/2020', 'deaths': 0.0})]
# (Background on this error at: http://sqlalche.me/e/f405)

# %% [markdown]
# ### Use pandas to load json converted DataFrame into database

# %%
ebola_virus.to_sql(name='ebola_virus', con=engine, if_exists='append', index=False)

# %%
sars_virus.to_sql(name='sars_virus', con=engine, if_exists='append', index=False)

# %%
swineflu_virus.to_sql(name='swineflu_virus', con=engine, if_exists='append', index=False)

# %% [markdown]
# ### Confirm data has been added by querying the ebola_virus table

# %%
#TABLE - EBOLA VIRUS

pd.read_sql_query('select * from ebola_virus', con=engine).head()
# Out:
#    id       country        date  cases_confirmed  deaths_confirmed
# 0   1        Guinea  2014-08-29            482.0             287.0
# 1   2       Nigeria  2014-08-29             15.0               6.0
# 2   3  Sierra Leone  2014-08-29            935.0             380.0
# 3   4       Liberia  2014-08-29            322.0             225.0
# 4   5  Sierra Leone  2014-09-05           1146.0             443.0

# %%
#TABLE - SARS VIRUS
pd.read_sql_query('select * from sars_virus', con=engine).head()
# Out:
#    id               country        date  cases_confirmed  deaths_confirmed
# 0   1               Germany  2003-03-17                1                 0
# 1   2                Canada  2003-03-17                8                 2
# 2   3             Singapore  2003-03-17               20                 0
# 3   4  Hong Kong SAR, China  2003-03-17               95                 1
# 4   5           Switzerland  2003-03-17                2                 0

# %%
#TABLE - SWINE FLU VIRUS
pd.read_sql_query('select * from swineflu_virus', con=engine).head()
# Out:
#    id              country  cases_confirmed  deaths_confirmed        date
# 0   1              Algeria                5               0.0  2009-07-06
# 1   2  Antigua and Barbuda                2               0.0  2009-07-06
# 2   3            Argentina             2485              60.0  2009-07-06
# 3   4            Australia             5298              10.0  2009-07-06
# 4   5              Austria               19               0.0  2009-07-06
